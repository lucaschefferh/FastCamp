# %%
#importação das bibliotecas
import cv2
import matplotlib.pyplot as plt
import glob
import os

# %%
#passando o nome da pasta onde estão as imagens
nome_da_pasta = "sala" 
arquivos_na_pasta = os.listdir(nome_da_pasta)

#criando lista para receber os caminhos de cada uma das imagens
caminhos = []
for padrao in padroes:
    caminhos.extend(glob.glob(os.path.join(nome_da_pasta, padrao)))

#ordenar para manter a ordem das imagens correta
caminhos = sorted(caminhos)

#lendo as imagens
lista_imagens = []
for caminho in caminhos:
    img = cv2.imread(caminho)
    if img is not None:
        lista_imagens.append(img)

# %%
#plotando as imagens em ordem
plt.figure(figsize=(20, 10))
for i, img in enumerate(lista_imagens):
    plt.subplot(1, len(lista_imagens), i + 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title(f"Parte {i+1}")

# %%
#criando o stitcher
stitcher = cv2.Stitcher_create()

#juntando as imagens
status, panorama = costurador.stitch(lista_imagens)

#salvando imagem final
cv2.imwrite("resultado_panorama.jpg", panorama)

#plotando o resultado
plt.figure(figsize=(20, 10))
plt.imshow(cv2.cvtColor(panorama, cv2.COLOR_BGR2RGB))
plt.title("Panorama Final")
plt.axis('off')
plt.show()
