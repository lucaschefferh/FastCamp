# %%
# !pip install transformers

# %%
import transformers
from transformers import pipeline

# %%
#carregando a pipeline de geração de texto junto do modelo
gerador = pipeline("text-generation", model="pierreguillou/gpt2-small-portuguese")
# Out:
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B /  510MB
# pytorch_model.bin: downloading bytes:           |  0.00B
# model.safetensors: reconstructing file:   0%|          |  0.00B /  510MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/149 [00:00<?, ?it/s]
# [transformers] GPT2LMHeadModel LOAD REPORT from: pierreguillou/gpt2-small-portuguese
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# transformer.h.{0...11}.attn.masked_bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/92.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/850k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/508k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]

# %%
#passando o texto e vendo o resultado
texto = "Em sentido estrito, ciência refere-se ao sistema de adquirir conhecimento baseado no método científico."
resultado = gerador(texto, max_length=60, do_sample=True)
print(resultado)
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'do_sample', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': 'Em sentido estrito, ciência refere-se ao sistema de adquirir conhecimento baseado no método científico. O método científico é a abordagem científica que visa a conhecer o mundo, com objetivo de compreender e explicar fenômenos.\n\nA ciência é a ciência básica e a ciência aplicada. É a ciência que estuda fenômenos em sua totalidade. Como a ciência é um artefato fundamental na formação da sociedade, as ciências são as ferramentas fundamentais do conhecimento humano.\n\nA ciência pode ser dividida em cinco grandes grupos principais:\n\n\n\nUm dos maiores problemas da ciência é que, em seus processos e métodos, os fenômenos são estudados de forma sistemática e/ou sistemática, com base em diferentes fatores.\n\n\n\n\n\n\n\n\n\n\n\n\n\nA ciência é a ciência que estuda e estuda fenômenos em suas totalidade. Como a ciência é uma artefato fundamental na formação da sociedade, as ciências são as ferramentas fundamentais do conhecimento humano.\n\n\nA ciência pode ser dividida em cinco grandes grupos principais:\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOs principais problemas são:\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]
